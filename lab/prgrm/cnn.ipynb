# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

# %%
(x_train,y_train),(x_test,y_test)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
def plot_sample(x,y,index):
  plt.figure(figsize=(14,2))
  plt.imshow(x[index])
  plt.xlabel(y[index])

# %%
plot_sample(x_train,y_train,2)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
x_train=x_train/255
x_test=x_test/255

# %%
cnn=models.Sequential()

cnn.add(layers.Conv2D(filters=32,activation='relu',kernel_size=(3,3),input_shape=(32,32,3)))
cnn.add(layers.MaxPooling2D(2,2))
                       
cnn.add(layers.Conv2D(filters=64,activation='relu',kernel_size=(3,3)))
cnn.add(layers.MaxPooling2D(2,2))

cnn.add(layers.Flatten())
cnn.add(layers.Dense(64,activation='relu'))
cnn.add(layers.Dense(10))

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 64)                147520
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 167,562
# Trainable params: 167,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
cnn.fit(x_train,y_train,epochs=25,validation_data=(x_train,y_train))
# Out:
# Epoch 1/25
# 1563/1563 [==============================] - 90s 57ms/step - loss: 1.5059 - accuracy: 0.4575 - val_loss: 1.2340 - val_accuracy: 0.5640
# Epoch 2/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 1.1525 - accuracy: 0.5960 - val_loss: 1.0532 - val_accuracy: 0.6311
# Epoch 3/25
# 1563/1563 [==============================] - 76s 48ms/step - loss: 1.0252 - accuracy: 0.6462 - val_loss: 1.0052 - val_accuracy: 0.6490
# Epoch 4/25
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.9465 - accuracy: 0.6715 - val_loss: 0.8833 - val_accuracy: 0.6952
# Epoch 5/25
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.8868 - accuracy: 0.6935 - val_loss: 0.8406 - val_accuracy: 0.7074
# Epoch 6/25
# 1563/1563 [==============================] - 76s 48ms/step - loss: 0.8358 - accuracy: 0.7110 - val_loss: 0.7694 - val_accuracy: 0.7338
# Epoch 7/25
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.7907 - accuracy: 0.7261 - val_loss: 0.7275 - val_accuracy: 0.7452
# Epoch 8/25
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.7516 - accuracy: 0.7401 - val_loss: 0.6810 - val_accuracy: 0.7666
# Epoch 9/25
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.7169 - accuracy: 0.7522 - val_loss: 0.6733 - val_accuracy: 0.7686
# Epoch 10/25
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.6863 - accuracy: 0.7608 - val_loss: 0.6132 - val_accuracy: 0.7920
# Epoch 11/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.6594 - accuracy: 0.7695 - val_loss: 0.6073 - val_accuracy: 0.7850
# Epoch 12/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.6305 - accuracy: 0.7804 - val_loss: 0.5796 - val_accuracy: 0.7997
# Epoch 13/25
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.6026 - accuracy: 0.7893 - val_loss: 0.5540 - val_accuracy: 0.8083
# Epoch 14/25
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.5777 - accuracy: 0.7985 - val_loss: 0.4861 - val_accuracy: 0.8337
# Epoch 15/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.5526 - accuracy: 0.8073 - val_loss: 0.4900 - val_accuracy: 0.8307
# Epoch 16/25
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.5326 - accuracy: 0.8130 - val_loss: 0.5215 - val_accuracy: 0.8168
# Epoch 17/25
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.5100 - accuracy: 0.8218 - val_loss: 0.4374 - val_accuracy: 0.8504
# Epoch 18/25
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4892 - accuracy: 0.8293 - val_loss: 0.4022 - val_accuracy: 0.8613
# Epoch 19/25
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.4700 - accuracy: 0.8340 - val_loss: 0.4436 - val_accuracy: 0.8429
# Epoch 20/25
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.4518 - accuracy: 0.8425 - val_loss: 0.4186 - val_accuracy: 0.8529
# Epoch 21/25
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.4330 - accuracy: 0.8481 - val_loss: 0.3602 - val_accuracy: 0.8762
# Epoch 22/25
# 1563/1563 [==============================] - 80s 51ms/step - loss: 0.4191 - accuracy: 0.8524 - val_loss: 0.3610 - val_accuracy: 0.8735
# Epoch 23/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.4038 - accuracy: 0.8572 - val_loss: 0.3379 - val_accuracy: 0.8843
# Epoch 24/25
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.3896 - accuracy: 0.8618 - val_loss: 0.3279 - val_accuracy: 0.8858
# Epoch 25/25
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.3683 - accuracy: 0.8708 - val_loss: 0.3228 - val_accuracy: 0.8860

# %%
y_pred=cnn.predict(x_test)

# %%
cnn.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2287 - accuracy: 0.6848
# [1.228654146194458, 0.6848000288009644]

# %%
y_test=y_test.reshape(-1)
y_pred=cnn.predict(x_test)

# %%
y_classes=[np.argmax(element) for element in y_pred]
print("classification report :\n",classification_report(y_test,y_classes))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72      1000
#            1       0.82      0.77      0.79      1000
#            2       0.60      0.57      0.59      1000
#            3       0.53      0.44      0.48      1000
#            4       0.70      0.57      0.62      1000
#            5       0.50      0.72      0.59      1000
#            6       0.81      0.73      0.77      1000
#            7       0.73      0.74      0.73      1000
#            8       0.78      0.78      0.78      1000
#            9       0.77      0.76      0.77      1000
#
#     accuracy                           0.68     10000
#    macro avg       0.69      0.68      0.68     10000
# weighted avg       0.69      0.68      0.68     10000
